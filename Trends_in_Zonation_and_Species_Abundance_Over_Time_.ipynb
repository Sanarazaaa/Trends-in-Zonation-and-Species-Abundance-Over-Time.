# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanarazaaa/Trends-in-Zonation-and-Species-Abundance-Over-Time./blob/main/Trends_in_Zonation_and_Species_Abundance_Over_Time_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('dataset - Sheet1.csv')  # Replace with your actual file path

# Group by Year and Zonation Level to analyze shifts
zonation_analysis = df.groupby(['Year', 'Zonation Level']).agg({'Abundance': 'sum'}).reset_index()

# Display the zonation analysis
print(zonation_analysis)

# Plotting shifts in zonation over the years
plt.figure(figsize=(12, 6))
sns.lineplot(data=zonation_analysis, x='Year', y='Abundance', hue='Zonation Level', marker='o')
plt.title('Trends in Abundance by Zonation Level Over Years')
plt.xlabel('Year')
plt.ylabel('Total Abundance')
plt.legend(title='Zonation Level')
plt.grid()
plt.show()
# Out:
#    Year Zonation Level  Abundance
# 0     1           High        840
# 1     1            Low        510
# 2     1            Mid        810
# 3     2           High        810
# 4     2            Low        260
# 5     2            Mid        590
# 6     3           High        775
# 7     3            Low        240
# 8     3            Mid        535

# %%
# Group by Year and Species to analyze abundance trends
abundance_analysis = df.groupby(['Year', 'Species']).agg({'Abundance': 'sum'}).reset_index()

# Plotting abundance trends over the years for a specific species
plt.figure(figsize=(12, 6))
sns.lineplot(data=abundance_analysis, x='Year', y='Abundance', hue='Species', marker='o')
plt.title('Trends in Abundance by Species Over Years')
plt.xlabel('Year')
plt.ylabel('Total Abundance')
plt.legend(title='Species', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid()
plt.show()
